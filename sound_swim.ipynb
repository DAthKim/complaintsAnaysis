# %%
pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 448 kB 57.7 MB/s
# ...
#      |████████████████████████████████| 86 kB 3.4 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
okt = Okt()
import matplotlib.font_manager as fm
import re
from PIL import Image
from io import BytesIO 
import datetime
from collections import Counter

# %%
labels = ['place','date','messenger','category','type','due','summary','name','phone','email','detail','receive','address','end','period','address_detail','result','result_detail','sign','etc']
data_swm = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sounds/sounds_place_swim.csv', names = labels, encoding='cp949')
data_swm.head()
# Out:
#        place        date  messenger  ...  result_detail  sign  etc
# NaN    place        date  messenger  ...  result_detail  sign  etc
# 601.0  보람수영장  2021-09-16      시민의소리  ...             --     O   --
# 599.0  보람수영장  2021-09-15      시민의소리  ...             --     O   --
# 589.0  보람수영장  2021-09-03      시민의소리  ...             --     O   --
# 583.0  보람수영장  2021-08-23      시민의소리  ...             --     O   --
#
# [5 rows x 20 columns]

# %%
circle_mask = np.array(Image.open('/content/drive/MyDrive/Colab Notebooks/circle_img.jpg'))

# %%
swm_detail = data_swm['detail']
swm_d_tolist = swm_detail.values.tolist()
swm_d_list = ''
for i in swm_d_tolist:
  swm_d_list += i
swm_d_nouns = okt.nouns(swm_d_list)
swm_d_n = ''
for i in swm_d_nouns:
  swm_d_n += i+' '
swm_d_nouns_count = Counter(swm_d_nouns)
stopwords = set(STOPWORDS)
stopwords.update(['수영장','보람'])

# %%
wd_swm_d = WordCloud(max_font_size=200,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(swm_d_n)
fig = plt.figure()
plt.imshow(wd_swm_d, interpolation='bilinear')
plt.axis('off')
wd_swm_d.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_swm_d.jpg')

# %%
swm_question = data_swm[data_swm['type'] == "질의"]
swm_question_detail = swm_question['detail']

swm_check = data_swm[data_swm['type'] == "확인"]
swm_check_detail = swm_check['detail']

swm_request = data_swm[data_swm['type'] == "건의"]
swm_request_detail = swm_request['detail']

# %% [markdown]
# 질의

# %%
swm_qd_tolist = swm_question_detail.values.tolist()
swm_qd_list = ''
for i in swm_qd_tolist:
  swm_qd_list += i

# %%
swm_qd_nouns = okt.nouns(swm_qd_list)
swm_qd_n = ''
for i in swm_qd_nouns:
  swm_qd_n += i+' '

# %%
swm_qd_nouns_count = Counter(swm_qd_nouns)
swm_qd_nouns_count
# Out:
# Counter({'가까이': 1,
#          '가능': 4,
#          '가능성': 1,
#          '가드': 3,
#          '가방': 1,
#          '가요': 2,
#          '가이드': 1,
#          '가입': 3,
#          '가족': 2,
#          '가지': 1,
#          '값': 2,
#          '강사': 4,
#          '강습': 6,
#          '강의': 1,
#          '개관': 2,
#          '개반': 1,
#          '개설': 3,
#          '개월': 1,
#          '개장': 2,
#          '거': 1,
#          '거주': 1,
#          '거치': 2,
#          '걱정': 1,
#          '건의': 1,
#          '걸': 2,
#          '것': 15,
#          '게': 1,
#          '게시': 1,
#          '겨우': 1,
#          '결과': 1,
#          '결제': 5,
#          '경우': 1,
#          '경쟁률': 1,
#          '계': 1,
#          '계속': 4,
#          '계획': 4,
#          '고급': 3,
#          '고민': 1,
#          '고요': 1,
#          '곳': 1,
#          '공개': 5,
#          '공고': 2,
#          '공단': 2,
#          '공지': 4,
#          '과': 1,
#          '과연': 1,
#          '과정': 1,
#          '관': 2,
#          '관계': 1,
#          '관련': 4,
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(['수영장','보람'])

# %%
wd_swm_qd = WordCloud(max_font_size=250,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(swm_qd_n)
fig = plt.figure()
plt.imshow(wd_swm_qd, interpolation='bilinear')
plt.axis('off')
wd_swm_qd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_swm_qd.jpg')

# %% [markdown]
# 확인

# %%
swm_cd_tolist = swm_check_detail.values.tolist()
swm_cd_list = ''
for i in swm_cd_tolist:
  swm_cd_list += i

# %%
swm_cd_nouns = okt.nouns(swm_cd_list)
swm_cd_n = ''
for i in swm_cd_nouns:
  swm_cd_n += i+' '

# %%
swm_cd_nouns_count = Counter(swm_cd_nouns)
swm_cd_nouns_count
# Out:
# Counter({'간편': 1,
#          '개장': 1,
#          '걸': 2,
#          '결과': 1,
#          '결재': 1,
#          '결제': 7,
#          '계속': 1,
#          '단계': 1,
#          '당첨': 1,
#          '료': 1,
#          '마지막': 1,
#          '멘트': 2,
#          '모두': 1,
#          '모바일': 1,
#          '문의': 1,
#          '문자': 1,
#          '삼성': 1,
#          '상황': 1,
#          '수강': 1,
#          '수영': 1,
#          '수영장': 3,
#          '시': 1,
#          '시도': 1,
#          '시스템': 1,
#          '실행': 1,
#          '안내': 3,
#          '어제': 1,
#          '에러': 1,
#          '여러': 1,
#          '연결': 2,
#          '오늘': 1,
#          '오류': 2,
#          '오픈': 1,
#          '완료': 2,
#          '유선': 1,
#          '자꾸': 1,
#          '자유': 1,
#          '전화': 3,
#          '조치': 1,
#          '진행': 1,
#          '카드': 1,
#          '코로나': 2,
#          '페이': 1,
#          '페이지': 1,
#          '확인': 2,
#          '회신': 1,
#          '휴장': 1})

# %%
stopwords = set(STOPWORDS)
stopwords.update(['수영장'])

# %%
wd_swm_cd = WordCloud(max_font_size=300,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(swm_cd_n)
fig = plt.figure()
plt.imshow(wd_swm_cd, interpolation='bilinear')
plt.axis('off')
wd_swm_cd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_swm_cd.jpg')

# %% [markdown]
# 건의

# %%
swm_rd_tolist = swm_request_detail.values.tolist()
swm_rd_list = ''
for i in swm_rd_tolist:
  swm_rd_list += i

# %%
swm_rd_nouns = okt.nouns(swm_rd_list)
swm_rd_n = ''
for i in swm_rd_nouns:
  swm_rd_n += i+' '

# %%
swm_rd_nouns_count = Counter(swm_rd_nouns)
swm_rd_nouns_count
# Out:
# Counter({'보람': 38,
#          '수영장': 93,
#          '이용자': 8,
#          '우선': 5,
#          '항상': 2,
#          '친절': 1,
#          '성의': 2,
#          '운영': 20,
#          '주시': 4,
#          '직원': 8,
#          '감사': 5,
#          '탈의': 2,
#          '실내': 2,
#          '비치': 2,
#          '헤어': 2,
#          '드라이기': 2,
#          '이용': 41,
#          '관련': 4,
#          '건의': 9,
#          '드릴': 1,
#          '글': 9,
#          '생각': 25,
#          '인원': 13,
#          '온': 2,
#          '몸': 3,
#          '제': 19,
#          '유난': 1,
#          '묘사': 1,
#          '일반': 4,
#          '머리': 4,
#          '말리': 3,
#          '분': 30,
#          '명중': 1,
#          '명': 11,
#          '본인': 3,
#          '음모': 1,
#          '엉덩이': 1,
#          '항문': 1,
#          '겨드랑이': 1,
#          '심지어': 1,
#          '발': 5,
#          '탁': 1,
#          '상위': 1,
#          '발가락': 1,
#          '모습': 4,
#          '대부분': 5,
#          '나이': 1,
#          '용품': 3,
#          '곳': 10,
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(['수영장','보람'])

# %%
wd_swm_rd = WordCloud(max_font_size=250,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(swm_rd_n)
fig = plt.figure()
plt.imshow(wd_swm_rd, interpolation='bilinear')
plt.axis('off')
wd_swm_rd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_swm_rd.jpg')
