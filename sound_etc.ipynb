# %%
pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 448 kB 54.7 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.6 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
okt = Okt()
import matplotlib.font_manager as fm
import re
from PIL import Image
from io import BytesIO 
import datetime
from collections import Counter

# %%
labels = ['place','date','messenger','category','type','due','summary','name','phone','email','detail','receive','address','end','period','address_detail','result','result_detail','sign','etc']
data_etc = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sounds/sounds_place_etc.csv', names = labels, encoding='cp949')
data_etc.head()
# Out:
#        place        date  messenger  ...  result_detail  sign    etc
# NaN    place        date  messenger  ...  result_detail  sign    etc
# 597.0     기타  2021-09-13      시민의소리  ...             --     O     --
# 571.0     기타  2021-08-03      시민의소리  ...             --     O  이첩 완료
# 558.0     기타  2021-06-22      시민의소리  ...             --     O     --
# 546.0     기타  2021-06-07      시민의소리  ...             --     O  이첩 완료
#
# [5 rows x 20 columns]

# %%
circle_mask = np.array(Image.open('/content/drive/MyDrive/Colab Notebooks/circle_img.jpg'))

# %%
etc_detail = data_etc['detail']
etc_d_tolist = etc_detail.values.tolist()
etc_d_list = ''
for i in etc_d_tolist:
  etc_d_list += i
etc_d_nouns = okt.nouns(etc_d_list)
etc_d_n = ''
for i in etc_d_nouns:
  etc_d_n += i+' '
etc_d_nouns_count = Counter(etc_d_nouns)
stopwords = set(STOPWORDS)
# stopwords.update(['아파트', '행복'])

# %%
wd_etc_d = WordCloud(max_font_size=200,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(etc_d_n)
fig = plt.figure()
plt.imshow(wd_etc_d, interpolation='bilinear')
plt.axis('off')
wd_etc_d.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_etc_d.jpg')

# %%
etc_question = data_etc[data_etc['type'] == "질의"]
etc_question_detail = etc_question['detail']

etc_check = data_etc[data_etc['type'] == "확인"]
etc_check_detail = etc_check['detail']

etc_request = data_etc[data_etc['type'] == "건의"]
etc_request_detail = etc_request['detail']

# %% [markdown]
# 질의

# %%
etc_qd_tolist = etc_question_detail.values.tolist()
etc_qd_list = ''
for i in etc_qd_tolist:
  etc_qd_list += i

# %%
etc_qd_nouns = okt.nouns(etc_qd_list)
etc_qd_n = ''
for i in etc_qd_nouns:
  etc_qd_n += i+' '

# %%
etc_qd_nouns_count = Counter(etc_qd_nouns)
etc_qd_nouns_count
# Out:
# Counter({'가산': 1,
#          '가요': 1,
#          '개관': 1,
#          '개장': 2,
#          '갸': 1,
#          '거나': 1,
#          '건설': 1,
#          '걸': 2,
#          '검토': 1,
#          '것': 3,
#          '게시': 1,
#          '결제': 2,
#          '경감': 1,
#          '계좌': 1,
#          '계획': 2,
#          '고추': 1,
#          '골대': 1,
#          '곳': 1,
#          '공단': 4,
#          '공원': 3,
#          '관련': 1,
#          '관리': 1,
#          '궁금증': 1,
#          '그': 1,
#          '근무': 1,
#          '근처': 1,
#          '금강': 2,
#          '급': 1,
#          '기억': 1,
#          '깜빡': 1,
#          '꼭': 1,
#          '나중': 1,
#          '내': 5,
#          '내부': 2,
#          '다시': 1,
#          '다정동': 1,
#          '답변': 1,
#          '대상': 1,
#          '대전': 1,
#          '대해': 1,
#          '더': 1,
#          '데크': 2,
#          '도움': 1,
#          '도토리': 1,
#          '듯': 1,
#          '등': 7,
#          '등등': 1,
#          '등록': 1,
#          '등지': 1,
#          '때문': 1,
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(['세종'])

# %%
wd_etc_qd = WordCloud(max_font_size=250,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(etc_qd_n)
fig = plt.figure()
plt.imshow(wd_etc_qd, interpolation='bilinear')
plt.axis('off')
wd_etc_qd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_etc_qd.jpg')

# %% [markdown]
# 확인

# %%
etc_cd_tolist = etc_check_detail.values.tolist()
etc_cd_list = ''
for i in etc_cd_tolist:
  etc_cd_list += i

# %%
etc_cd_nouns = okt.nouns(etc_cd_list)
etc_cd_n = ''
for i in etc_cd_nouns:
  etc_cd_n += i+' '

# %%
etc_cd_nouns_count = Counter(etc_cd_nouns)
etc_cd_nouns_count
# Out:
# Counter({'기': 1,
#          '반환': 2,
#          '서류': 1,
#          '시기': 1,
#          '요청': 1,
#          '우편': 1,
#          '월': 1,
#          '응모': 1,
#          '임원': 1,
#          '전화': 1,
#          '청구': 1})

# %%
stopwords = set(STOPWORDS)
# stopwords.update(['캠핑장','합강 캠핑장','합강'])

# %%
wd_etc_cd = WordCloud(max_font_size=300,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(etc_cd_n)
fig = plt.figure()
plt.imshow(wd_etc_cd, interpolation='bilinear')
plt.axis('off')
wd_etc_cd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_etc_cd.jpg')

# %% [markdown]
# 건의

# %%
etc_rd_tolist = etc_request_detail.values.tolist()
etc_rd_list = ''
for i in etc_rd_tolist:
  etc_rd_list += i

# %%
etc_rd_nouns = okt.nouns(etc_rd_list)
etc_rd_n = ''
for i in etc_rd_nouns:
  etc_rd_n += i+' '

# %%
etc_rd_nouns_count = Counter(etc_rd_nouns)
etc_rd_nouns_count
# Out:
# Counter({'가기': 1,
#          '가나': 1,
#          '가능': 1,
#          '가면': 1,
#          '가산': 1,
#          '가요': 3,
#          '가장': 1,
#          '가족': 1,
#          '가지': 1,
#          '가칭': 1,
#          '각': 2,
#          '각각': 1,
#          '간': 1,
#          '간다': 1,
#          '간의': 1,
#          '감당': 1,
#          '감사': 4,
#          '갑자기': 1,
#          '강당': 1,
#          '강습': 2,
#          '강의': 1,
#          '개': 3,
#          '개방': 9,
#          '개선': 4,
#          '개성': 1,
#          '개인': 3,
#          '개체': 1,
#          '개학': 1,
#          '거': 7,
#          '거나': 3,
#          '거듭': 1,
#          '거의': 1,
#          '거주': 3,
#          '거주지': 17,
#          '건가': 3,
#          '건강': 1,
#          '건물': 1,
#          '건의': 9,
#          '걸': 1,
#          '검사': 1,
#          '검토': 4,
#          '겁': 2,
#          '것': 31,
#          '것입': 1,
#          '게': 3,
#          '게시': 2,
#          '게시판': 1,
#          '게임': 1,
#          '격양됨': 1,
#          '결정': 2,
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(['세종시'])

# %%
wd_etc_rd = WordCloud(max_font_size=250,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(etc_rd_n)
fig = plt.figure()
plt.imshow(wd_etc_rd, interpolation='bilinear')
plt.axis('off')
wd_etc_rd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_etc_rd.jpg')
