# %%
pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 5.9 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 448 kB 44.7 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
okt = Okt()
import matplotlib.font_manager as fm
import re
from PIL import Image
from io import BytesIO 
import datetime
from collections import Counter

# %%
labels = ['place','date','messenger','category','type','due','summary','name','phone','email','detail','receive','address','end','period','address_detail','result','result_detail','sign','etc']
data_ct = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sounds/sounds_place_cluster.csv', names = labels, encoding='cp949')
data_ct.head()
# Out:
#          place        date  messenger  ...  result_detail  sign  etc
# NaN      place        date  messenger  ...  result_detail  sign  etc
# 577.0  산학연클러스터  2021-08-13       고객카드  ...             --     O   --
# 500.0  산학연클러스터  2021-02-16       고객카드  ...             --     O   --
# 482.0  산학연클러스터  2020-12-18       고객카드  ...             --     O   --
# 481.0  산학연클러스터  2020-12-18       고객카드  ...             --     O   --
#
# [5 rows x 20 columns]

# %%
circle_mask = np.array(Image.open('/content/drive/MyDrive/Colab Notebooks/circle_img.jpg'))

# %%
ct_detail = data_ct['detail']
ct_d_tolist = ct_detail.values.tolist()
ct_d_list = ''
for i in ct_d_tolist:
  ct_d_list += i
ct_d_nouns = okt.nouns(ct_d_list)
ct_d_n = ''
for i in ct_d_nouns:
  ct_d_n += i+' '
ct_d_nouns_count = Counter(ct_d_nouns)
stopwords = set(STOPWORDS)
# stopwords.update(['아파트', '행복'])

# %%
wd_ct_d = WordCloud(max_font_size=200,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(ct_d_n)
fig = plt.figure()
plt.imshow(wd_ct_d, interpolation='bilinear')
plt.axis('off')
wd_ct_d.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_ct_d.jpg')

# %%
ct_question = data_ct[data_ct['type'] == "질의"]
ct_question_detail = ct_question['detail']

ct_check = data_ct[data_ct['type'] == "확인"]
ct_check_detail = ct_check['detail']

ct_request = data_ct[data_ct['type'] == "건의"]
ct_request_detail = ct_request['detail']

# %% [markdown]
# 질의

# %%
ct_qd_tolist = ct_question_detail.values.tolist()
ct_qd_list = ''
for i in ct_qd_tolist:
  ct_qd_list += i

# %%
ct_qd_nouns = okt.nouns(ct_qd_list)
ct_qd_n = ''
for i in ct_qd_nouns:
  ct_qd_n += i+' '

# %%
ct_qd_nouns_count = Counter(ct_qd_nouns)
ct_qd_nouns_count
# Out:
# Counter({'기세': 1,
#          '기업': 1,
#          '더': 1,
#          '문제': 1,
#          '별': 1,
#          '복도': 3,
#          '분': 1,
#          '설치': 1,
#          '업체': 1,
#          '에어컨': 3,
#          '여름': 1,
#          '차이': 1,
#          '청소': 1,
#          '층': 4})

# %%
stopwords = set(STOPWORDS)
# stopwords.update(['세종'])

# %%
wd_ct_qd = WordCloud(max_font_size=250,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(ct_qd_n)
fig = plt.figure()
plt.imshow(wd_ct_qd, interpolation='bilinear')
plt.axis('off')
wd_ct_qd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_ct_qd.jpg')

# %% [markdown]
# 확인

# %%
ct_cd_tolist = ct_check_detail.values.tolist()
ct_cd_list = ''
for i in ct_cd_tolist:
  ct_cd_list += i

# %%
ct_cd_nouns = okt.nouns(ct_cd_list)
ct_cd_n = ''
for i in ct_cd_nouns:
  ct_cd_n += i+' '

# %%
ct_cd_nouns_count = Counter(ct_cd_nouns)
ct_cd_nouns_count
# Out:
# Counter()

# %%
stopwords = set(STOPWORDS)
# stopwords.update(['캠핑장','합강 캠핑장','합강'])

# %%
wd_ct_cd = WordCloud(max_font_size=300,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(ct_cd_n)
fig = plt.figure()
plt.imshow(wd_etc_cd, interpolation='bilinear')
plt.axis('off')
wd_ct_cd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_ct_cd.jpg')

# %% [markdown]
# 건의

# %%
ct_rd_tolist = ct_request_detail.values.tolist()
ct_rd_list = ''
for i in ct_rd_tolist:
  ct_rd_list += i

# %%
ct_rd_nouns = okt.nouns(ct_rd_list)
ct_rd_n = ''
for i in ct_rd_nouns:
  ct_rd_n += i+' '

# %%
ct_rd_nouns_count = Counter(ct_rd_nouns)
ct_rd_nouns_count
# Out:
# Counter({'감안': 1,
#          '개선': 1,
#          '건립': 1,
#          '건물': 3,
#          '건의': 2,
#          '것': 1,
#          '공간': 2,
#          '관련': 2,
#          '관리': 1,
#          '구내식당': 1,
#          '내': 1,
#          '내용': 1,
#          '냄새': 1,
#          '대한': 1,
#          '등록': 2,
#          '때': 2,
#          '마련': 1,
#          '매우': 1,
#          '매점': 1,
#          '무분별': 1,
#          '민원': 2,
#          '및': 5,
#          '바람': 1,
#          '방음': 1,
#          '방지책': 1,
#          '방치': 1,
#          '보': 1,
#          '보임': 1,
#          '부족': 1,
#          '비치': 2,
#          '산학': 3,
#          '설치': 2,
#          '센터': 4,
#          '손': 1,
#          '송출': 2,
#          '시간': 1,
#          '시기': 1,
#          '시설': 1,
#          '시행': 2,
#          '쓰레기통': 1,
#          '안전': 3,
#          '업체': 1,
#          '역주행': 2,
#          '요구': 1,
#          '요청': 6,
#          '우려': 1,
#          '우리': 1,
#          '우측': 1,
#          '위': 2,
#          '음악': 2,
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(['산학','클러스터','센터','요청'])

# %%
wd_ct_rd = WordCloud(max_font_size=250,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(ct_rd_n)
fig = plt.figure()
plt.imshow(wd_ct_rd, interpolation='bilinear')
plt.axis('off')
wd_ct_rd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_ct_rd.jpg')
