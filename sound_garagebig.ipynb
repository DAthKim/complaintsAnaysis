# %%
pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 448 kB 46.8 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
okt = Okt()
import matplotlib.font_manager as fm
import re
from PIL import Image
from io import BytesIO 
import datetime
from collections import Counter

# %%
labels = ['place','date','messenger','category','type','due','summary','name','phone','email','detail','receive','address','end','period','address_detail','result','result_detail','sign','etc']
data_grb = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sounds/sounds_place_garagebig.csv', names = labels, encoding='cp949')
data_grb.head()
# Out:
#        place        date  messenger  ...  result_detail  sign  etc
# NaN    place        date  messenger  ...  result_detail  sign  etc
# 369.0  대형폐기물  2020-06-22      시민의소리  ...             --     O   --
# 365.0  대형폐기물  2020-06-10      시민의소리  ...             --     O   --
# 362.0  대형폐기물  2020-06-08      시민의소리  ...             --     O   --
# 317.0  대형폐기물  2020-02-24      시민의소리  ...             --     O   --
#
# [5 rows x 20 columns]

# %%
circle_mask = np.array(Image.open('/content/drive/MyDrive/Colab Notebooks/circle_img.jpg'))

# %%
grb_detail = data_grb['detail']
grb_d_tolist = grb_detail.values.tolist()
grb_d_list = ''
for i in grb_d_tolist:
  grb_d_list += i
grb_d_nouns = okt.nouns(grb_d_list)
grb_d_n = ''
for i in grb_d_nouns:
  grb_d_n += i+' '
grb_d_nouns_count = Counter(grb_d_nouns)
stopwords = set(STOPWORDS)
stopwords.update(['폐기물'])

# %%
wd_grb_d = WordCloud(max_font_size=200,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(grb_d_n)
fig = plt.figure()
plt.imshow(wd_grb_d, interpolation='bilinear')
plt.axis('off')
wd_grb_d.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_grb_d.jpg')

# %%
grb_question = data_grb[data_grb['type'] == "질의"]
grb_question_detail = grb_question['detail']

grb_check = data_grb[data_grb['type'] == "확인"]
grb_check_detail = grb_check['detail']

grb_request = data_grb[data_grb['type'] == "건의"]
grb_request_detail = grb_request['detail']

# %% [markdown]
# 질의

# %%
grb_qd_tolist = grb_question_detail.values.tolist()
grb_qd_list = ''
for i in grb_qd_tolist:
  grb_qd_list += i

# %%
grb_qd_nouns = okt.nouns(grb_qd_list)
grb_qd_n = ''
for i in grb_qd_nouns:
  grb_qd_n += i+' '

# %%
grb_qd_nouns_count = Counter(grb_qd_nouns)
grb_qd_nouns_count
# Out:
# Counter({'가격': 1,
#          '개': 1,
#          '걸': 1,
#          '경우': 3,
#          '공단': 1,
#          '관리': 2,
#          '구매': 1,
#          '구입': 1,
#          '답변': 1,
#          '대상': 1,
#          '대형': 2,
#          '도난': 2,
#          '도시': 1,
#          '될런지': 1,
#          '두번째': 1,
#          '등': 1,
#          '롤': 1,
#          '마대': 1,
#          '매트리스': 1,
#          '모습': 2,
#          '못': 1,
#          '문의': 2,
#          '문제': 1,
#          '발부': 1,
#          '발생': 2,
#          '방법': 3,
#          '방지': 2,
#          '배출': 1,
#          '번': 1,
#          '봉투': 2,
#          '부분': 1,
#          '부착': 1,
#          '분실': 1,
#          '분해': 1,
#          '불': 1,
#          '비교': 1,
#          '비용': 2,
#          '사진': 2,
#          '서랍': 2,
#          '세번': 1,
#          '세종': 1,
#          '수': 1,
#          '수거': 1,
#          '수고': 1,
#          '스티커': 7,
#          '시': 2,
#          '시설': 1,
#          '신청': 1,
#          '싱글': 2,
#          '알루미늄': 1,
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(['폐기물','대형'])

# %%
wd_grb_qd = WordCloud(max_font_size=250,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(grb_qd_n)
fig = plt.figure()
plt.imshow(wd_grb_qd, interpolation='bilinear')
plt.axis('off')
wd_grb_qd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_grb_qd.jpg')

# %% [markdown]
# 확인

# %%
grb_cd_tolist = grb_check_detail.values.tolist()
grb_cd_list = ''
for i in grb_cd_tolist:
  grb_cd_list += i

# %%
grb_cd_nouns = okt.nouns(grb_cd_list)
grb_cd_n = ''
for i in grb_cd_nouns:
  grb_cd_n += i+' '

# %%
grb_cd_nouns_count = Counter(grb_cd_nouns)
grb_cd_nouns_count
# Out:
# Counter()

# %%
stopwords = set(STOPWORDS)
# stopwords.update(['캠핑장','합강 캠핑장','합강'])

# %%
wd_grb_cd = WordCloud(max_font_size=300,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(grb_cd_n)
fig = plt.figure()
plt.imshow(wd_grb_cd, interpolation='bilinear')
plt.axis('off')
wd_grb_cd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_grb_cd.jpg')

# %% [markdown]
# 건의

# %%
grb_rd_tolist = grb_request_detail.values.tolist()
grb_rd_list = ''
for i in grb_rd_tolist:
  grb_rd_list += i

# %%
grb_rd_nouns = okt.nouns(grb_rd_list)
grb_rd_n = ''
for i in grb_rd_nouns:
  grb_rd_n += i+' '

# %%
grb_rd_nouns_count = Counter(grb_rd_nouns)
grb_rd_nouns_count
# Out:
# Counter({'가정': 1,
#          '건': 1,
#          '검색': 1,
#          '것': 1,
#          '결재': 1,
#          '계': 1,
#          '공기청정기': 1,
#          '공단': 1,
#          '공지': 1,
#          '관련': 1,
#          '구매': 1,
#          '귀': 1,
#          '금액': 1,
#          '기도': 1,
#          '기름': 1,
#          '네이버': 3,
#          '누루': 1,
#          '다른': 2,
#          '다리미': 1,
#          '다시': 1,
#          '더': 2,
#          '듯': 1,
#          '를': 1,
#          '마을': 1,
#          '마치': 2,
#          '문의': 1,
#          '문제': 1,
#          '방문': 1,
#          '배출': 1,
#          '버튼': 1,
#          '부착': 1,
#          '부탁': 1,
#          '사용': 3,
#          '사이트': 3,
#          '세분': 2,
#          '수': 1,
#          '수가': 2,
#          '스티커': 3,
#          '시간': 1,
#          '신분': 1,
#          '신청': 2,
#          '아무': 1,
#          '안내': 1,
#          '알': 1,
#          '어디': 1,
#          '완료': 1,
#          '웨일': 2,
#          '이지': 1,
#          '이천원': 1,
#          '인터넷': 1,
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(['폐기물'])

# %%
wd_grb_rd = WordCloud(max_font_size=250,background_color="white",mask=circle_mask,font_path='/content/drive/MyDrive/Colab Notebooks/sounds/malgun.ttf',stopwords=stopwords).generate(grb_rd_n)
fig = plt.figure()
plt.imshow(wd_grb_rd, interpolation='bilinear')
plt.axis('off')
wd_grb_rd.to_file(filename='/content/drive/MyDrive/Colab Notebooks/wordcloud_img/wd_grb_rd.jpg')
