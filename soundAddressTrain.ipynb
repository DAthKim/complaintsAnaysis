# %%
pip install pandas

# %%
import pandas as pd

# %%
data01 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sounds.csv',encoding='cp949')
data01.head()
# Out:
#   민원사항 Unnamed: 1  Unnamed: 2  ... Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0   번호        사업장        민원일자  ...      처리결과사유    부서장 확인여부        기타사항
# 1  607         --  2021-09-29  ...          --          --          --
# 2  606         --  2021-09-29  ...          --          --          --
# 3  605         --  2021-09-25  ...          --          --          --
# 4  604     종촌동주차장  2021-09-24  ...          --           O          --
#
# [5 rows x 21 columns]

# %%
delete01 = data01.iloc[0]
delete01
# Out:
# 민원사항                 번호
# Unnamed: 1          사업장
# Unnamed: 2         민원일자
# Unnamed: 3         접수방식
# Unnamed: 4         민원분야
# Unnamed: 5         민원유형
# Unnamed: 6         처리기한
# Unnamed: 7         민원요약
# Unnamed: 8       민원인 성명
# Unnamed: 9      민원인 연락처
# Unnamed: 11      민원세부내용
# 민원처리                접수자
# Unnamed: 13       처리담당자
# Unnamed: 14       처리완료일
# Unnamed: 15      처리완료기간
# Unnamed: 16        처리내용
# Unnamed: 17        처리결과
# Unnamed: 18      처리결과사유
# Unnamed: 19    부서장 확인여부
# Unnamed: 20        기타사항
# Name: 민원인 이메일주소, dtype: object

# %%
data02 = data01.drop(delete01)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-d46e92400503> in <module>()
# ----> 1 data02 = data01.drop(delete01)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
# ...
